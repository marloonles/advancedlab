# %%
import numpy as np
import matplotlib.pyplot as plt

path = "/content/Advanced Lab 1 Data for Lab 3.csv"
data = np.genfromtxt(path, delimiter=',', names=['times','therm','potvalue'])

# %%
time = data['times']*0.001
thermvalue = data['therm']
potvalue = data['potvalue']

# %%
fig, ax1 = plt.subplots()

ax1.scatter(time, temp, s=4, color='blue', label='Thermistor Value')
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Thermistor Value (AU)')
ax1.set_title('Thermistor and Potentiometer Measurements')
ax1.grid()

ax2 = ax1.twinx()
ax2.scatter(time, potvalue, s=4, color='red', label='Potentiometer Value')
ax2.set_ylabel('Potentiometer Value (AU)')

fig.tight_layout()
fig.legend(loc='lower right', bbox_to_anchor=(0.87, 0.8))
plt.show()
